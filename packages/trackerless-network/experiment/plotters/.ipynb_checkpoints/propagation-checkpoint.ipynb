# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json

# %%
file = open("/Users/santeri/network-monorepo/packages/trackerless-network/results/propagation/2024-12-13T12-08-57-226Z/processed.csv", "r")
table = pd.read_csv(file, index_col=None, skipinitialspace=True)
df = table.sort_values(['nodes'])
df
# Out:
#     nodes  run  propagationTime       hops  messagesReceived
# 9      18    3       113.643791   3.620915                17
# 10     18    4        99.460784   3.500000                17
# 6      18    0       120.513072   3.398693                17
# 7      18    1       137.777778   3.261438                17
# 8      18    2       144.192810   3.604575                17
# 17     36    1       104.701587   4.317460                35
# 16     36    0       130.531746   4.435714                35
# 20     36    4       118.967460   4.541270                35
# 18     36    2       126.675397   4.429365                35
# 19     36    3       134.915873   4.145238                35
# 28     72    2       115.971635   5.341354                71
# 27     72    1       131.961463   5.239632                71
# 26     72    0       118.595657   5.384390                71
# 29     72    3       119.961854   5.264476                71
# 30     72    4       105.528560   5.499218                71
# 4     144    3       139.045843   6.681575               143
# 3     144    2       112.098873   6.916861               143
# 2     144    1       111.408023   7.021950               143
# 1     144    0       131.383061   6.822358               143
# 5     144    4       109.020008   7.064054               143
# 15    288    4       114.666848   8.211164               287
# 13    288    2       114.616459   8.306064               287
# 12    288    1       127.696404   8.400975               287
# 11    288    0       115.906758   8.097646               287
# 14    288    3       131.192557   8.417598               287
# 21    576    0       130.161141  10.422992               575
# 22    576    1       127.013231   9.935018               575
# 23    576    2       120.906676   9.826778               575
# 24    576    3       125.151368   9.689155               575
# 25    576    4       132.371748   9.943653               575
# 0    1152    0       116.575516  11.531474              1151

# %%
grouped = df.groupby(['nodes'])
avg = grouped.mean()
print(avg)
# Out:
#        run  propagationTime       hops  messagesReceived
# nodes
# 18       2       123.117647   3.477124                17
# 36       2       123.158413   4.373810                35
# 72       2       118.403834   5.345814                71
# 144      2       120.591162   6.901360               143
# 288      2       120.815805   8.286689               287
# 576      2       127.120833   9.963519               575
# 1152     0       116.575516  11.531474              1151

# %%
f, ax = plt.subplots(1)
xdata = avg.axes[0].tolist()
ydata = avg['propagationTime']
ax.plot(xdata, ydata)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1)
xdata = avg.axes[0].tolist()
ydata = avg['hops']
ax.plot(xdata, ydata)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1)
xdata = avg.axes[0].tolist()
ydata = avg['maxHops']
ax.plot(xdata, ydata)
ax.set_ylim(ymin=0)
plt.show(f)
