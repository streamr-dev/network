# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json

# %%
file = open("/Users/santeri/network-monorepo/packages/trackerless-network/results/propagation/2000-nodes/processed.csv", "r")
table = pd.read_csv(file, index_col=None, skipinitialspace=True)
df = table.sort_values(['nodes'])
df

meanUnderlayDelay = 75.11404595336083

# %%
grouped = df.groupby(['nodes'])
avg = grouped.mean()
print(avg)
# Out:
#        run  propagationTime       hops  messagesReceived    maxHops  \
# nodes
# 18       2       121.409150   3.469935                17   4.035294
# 36       2       130.179524   4.333333                35   5.051429
# 72       2       132.164867   5.496753                71   6.808451
# 144      2       116.368726   6.789705               143   8.590210
# 288      2       116.408145   8.329213               287  10.855052
# 576      2       126.822242   9.972816               575  13.063652
# 1152     2       126.380651  11.791640              1151  15.981755
# 2176     0       126.729356  13.565065              2175  18.188506
#
#        maxPropagationTime
# nodes
# 18             172.811765
# 36             209.828571
# 72             211.794366
# 144            199.647552
# 288            239.662021
# 576            252.858783
# 1152           283.351520
# 2176           277.743908

# %%
f, ax = plt.subplots(1, figsize=(15, 10))
xdata = avg.axes[0].tolist()
ydata = avg['propagationTime']
ax.plot(xdata, ydata)
ax.set_title('Mean Message Propagation Delay', fontsize=18)
ax.set_xlabel('Number of nodes', fontsize=12)
ax.set_ylabel('Time in ms', fontsize=12)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1, figsize=(18, 12))
xdata = avg.axes[0].tolist()
ydata = avg['hops']
ax.plot(xdata, ydata)
ax.set_title('Mean Number of Hops', fontsize=18)
ax.set_xlabel('Number of nodes', fontsize=12)
ax.set_ylabel('Number of Hops', fontsize=12)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1, figsize=(18, 12))
xdata = avg.axes[0].tolist()
ydata = avg['maxHops']
ax.plot(xdata, ydata)
ax.set_title('Max Number of Hops', fontsize=18)
ax.set_xlabel('Number of nodes', fontsize=12)
ax.set_ylabel('Number of Hops', fontsize=12)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1, figsize=(18, 12))
xdata = avg.axes[0].tolist()
ydata = avg['maxPropagationTime']
ax.plot(xdata, ydata)
ax.set_title('Max Message Propagation Delay', fontsize=18)
ax.set_xlabel('Number of nodes', fontsize=12)
ax.set_ylabel('Time in ms', , fontsize=12)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1, figsize=(18, 12))
xdata = avg.axes[0].tolist()
ydata = avg['propagationTime'] / meanUnderlayDelay
ax.plot(xdata, ydata)
ax.set_title('Mean Relative Delay Penalty', fontsize=18)
ax.set_xlabel('Number of nodes', fontsize=12)
ax.set_ylabel('Relative Delay Penalty', fontsize=12)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1, figsize=(18, 12))
xdata = avg.axes[0].tolist()
ydata = avg['maxPropagationTime'] / meanUnderlayDelay
ax.plot(xdata, ydata)
ax.set_title('Max Relative Delay Penalty', fontsize=18)
ax.set_xlabel('Number of nodes', fontsize=12)
ax.set_ylabel('Relative Delay Penalty', fontsize=12)
ax.set_ylim(ymin=0)
plt.show(f)
