# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json

# %%
file = open("/Users/santeri/network-monorepo/packages/trackerless-network/results/propagation/2024-12-16T12-16-14-110Z/processed.csv", "r")
table = pd.read_csv(file, index_col=None, skipinitialspace=True)
df = table.sort_values(['nodes'])
df
# Out:
#     nodes  run  propagationTime       hops  messagesReceived
# 14     18    4       121.581699   3.522876                17
# 13     18    3       138.415033   3.398693                17
# 12     18    2       118.591503   3.503268                17
# 11     18    1       113.558824   3.568627                17
# 10     18    0       114.898693   3.356209                17
# 21     36    0       152.396825   4.152381                35
# 23     36    2       113.920635   4.553968                35
# 24     36    3       119.460317   4.242063                35
# 25     36    4       137.113492   4.434921                35
# 22     36    1       128.006349   4.283333                35
# 34     72    3       113.941510   5.554577                71
# 35     72    4       106.936424   5.533646                71
# 31     72    0       140.982981   5.272105                71
# 32     72    1       142.104264   5.446205                71
# 33     72    2       156.859155   5.677230                71
# 7     144    2       114.792104   6.866744               143
# 6     144    1       120.182789   6.659479               143
# 5     144    0       109.300505   7.079060               143
# 8     144    3       125.640637   6.760247               143
# 9     144    4       111.927593   6.582993               143
# 17    288    1       124.831204   8.304624               287
# 19    288    3       115.453930   8.233946               287
# 18    288    2       120.875351   8.533887               287
# 16    288    0       108.656504   8.317944               287
# 20    288    4       112.223735   8.255662               287
# 26    576    0       124.931736   9.564167               575
# 27    576    1       126.908810  10.140915               575
# 28    576    2       136.952400  10.024771               575
# 29    576    3       118.321398  10.121329               575
# 30    576    4       126.996863  10.012899               575
# 4    1152    4       138.600823  12.008173              1151
# 3    1152    3       123.008794  11.751229              1151
# 2    1152    2       126.303000  11.796858              1151
# 1    1152    1       122.711152  11.752965              1151
# 0    1152    0       121.279487  11.648972              1151
# 15   2176    0       126.729356  13.565065              2175

# %%
grouped = df.groupby(['nodes'])
avg = grouped.mean()
print(avg)
# Out:
#        run  propagationTime       hops  messagesReceived
# nodes
# 18       2       121.409150   3.469935                17
# 36       2       130.179524   4.333333                35
# 72       2       132.164867   5.496753                71
# 144      2       116.368726   6.789705               143
# 288      2       116.408145   8.329213               287
# 576      2       126.822242   9.972816               575
# 1152     2       126.380651  11.791640              1151
# 2176     0       126.729356  13.565065              2175

# %%
f, ax = plt.subplots(1)
xdata = avg.axes[0].tolist()
ydata = avg['propagationTime']
ax.plot(xdata, ydata)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1)
xdata = avg.axes[0].tolist()
ydata = avg['hops']
ax.plot(xdata, ydata)
ax.set_ylim(ymin=0)
plt.show(f)

# %%
f, ax = plt.subplots(1)
xdata = avg.axes[0].tolist()
ydata = avg['maxHops']
ax.plot(xdata, ydata)
ax.set_ylim(ymin=0)
plt.show(f)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maxHops'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-d87e459b8b64> in <module>
#       1 f, ax = plt.subplots(1)
#       2 xdata = avg.axes[0].tolist()
# ----> 3 ydata = avg['maxHops']
#       4 ax.plot(xdata, ydata)
#       5 ax.set_ylim(ymin=0)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'maxHops'
